# %% [markdown]
# ## OpenAI API 키 발급 및 설정
#
# 1. OpenAI API 키 발급
#
# - [OpenAI API 키 발급방법](https://wikidocs.net/233342) 글을 참고해 주세요.
#
# 1. `.env` 파일 설정
#
# - 프로젝트 루트 디렉토리에 `.env` 파일을 생성합니다.
# - 파일에 API 키를 다음 형식으로 저장합니다:
#   `OPENAI_API_KEY` 에 발급받은 API KEY 를 입력합니다.
#
# - `.env` 파일에 발급한 API KEY 를 입력합니다.

# %%
# LangChain 업데이트
# !pip install -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt

# %% [markdown]
# 패키지 설치

# %%
# ** 주의: OS가 Windows일 경우, 긴 파일 이름 다룰 수 있게 설정해야한다.**
# >> https://learn.microsoft.com/en-us/windows/win32/fileio/maximum-file-path-limitation?tabs=powershell#enable-long-paths-in-windows-10-version-1607-and-later

# 패키지 설치
# !poetry update
# Out:
# Updating dependencies
# Resolving dependencies...
#
# Package operations: 104 installs, 1 update, 0 removals
#
#   - Installing jupyterlab-widgets (3.0.16)
#   - Installing absl-py (2.3.1)
#   - Installing altair (5.5.0)
#   - Installing anthropic (0.72.1)
#   - Installing appdirs (1.4.4)
#   - Installing azure-ai-inference (1.0.0b9)
#   - Installing azure-ai-projects (1.1.0b4)
#   - Installing azure-cosmos (4.14.1)
#   - Installing azure-identity (1.25.1)
#   - Installing azure-search-documents (11.6.0)
#   - Installing blinker (1.9.0)
#   - Installing chromadb (0.6.3)
#   - Installing cohere (5.20.0)
#   - Installing datasets (4.4.1)
#   - Installing deepl (1.25.0)
#   - Installing effdet (0.4.1)
#   - Installing elasticsearch (8.19.2)
#   - Installing emoji (2.15.0)
#   - Installing feedparser (6.0.12)
#   - Installing ftfy (6.3.1)
#   - Installing gitpython (3.1.45)
#   - Installing google-ai-generativelanguage (0.9.0)
#   - Installing google-cloud-vision (3.11.0)
#   - Installing html5lib (1.1)
#   - Installing instructor (1.12.0)
#   - Installing ipywidgets (8.1.8)
#   - Installing jupyter-console (6.6.3)
#   - Installing kiwipiepy (0.21.0)
#   - Installing konlpy (0.6.0)
#   - Installing langchain-community (0.3.31)
#   - Installing langchain-openai (0.3.35)
#   - Installing langdetect (1.0.9)
#   - Installing langgraph (0.6.11)
#   - Installing llama-cloud-services (0.6.21)
#   - Installing markdown (3.10)
#   - Installing msoffcrypto-tool (5.4.2)
#   - Installing notebook (7.4.7)
#   - Installing ollama (0.6.0)
#   - Installing openpyxl (3.1.5)
#   - Installing pathspec (0.12.1)
#   - Installing pdf2image (1.17.0)
#   - Installing pi-heif (0.22.0)
#   - Installing pikepdf (10.0.2)
#   - Installing pinecone-client (6.0.0)
#   - Installing pinecone-plugin-inference (3.1.0)
#   - Installing pinecone-text (0.11.0)
#   - Installing pyclipper (1.3.0.post6)
#   - Installing pydeck (0.9.1)
#   - Installing pymilvus (2.5.17)
#   - Installing pymupdf (1.26.6)
#   - Installing pypandoc (1.16)
#   - Installing python-docx (1.2.0)
#   - Installing python-iso639 (2025.11.11)
#   - Installing python-magic (0.4.27)
#   - Installing python-oxmsg (0.0.2)
#   - Installing python-pptx (1.0.2)
#   - Installing rank-bm25 (0.2.2)
#   - Installing scikit-network (0.33.3)
#   - Installing shapely (2.1.2)
#   - Installing striprtf (0.0.26)
#   - Installing tabulate (0.9.0)
#   - Installing tavily-python (0.7.12)
#   - Installing toml (0.10.2)
#   - Installing twine (6.2.0)
#   - Installing types-pyyaml (6.0.12.20250915)
#   - Installing unstructured-client (0.42.3)
#   - Installing unstructured-inference (1.1.1)
#   - Installing unstructured-pytesseract (0.3.15)
#   - Installing watchdog (6.0.0)
#   - Installing xlrd (2.0.2)
#   - Installing arxiv (2.3.0)
#   - Installing docx2txt (0.9)
#   - Installing faiss-cpu (1.12.0)
#   - Installing flashrank (0.2.10)
#   - Installing google-search-results (2.4.2)
#   - Installing grandalf (0.8)
#   - Installing jupyter (1.1.1)
#   - Installing langchain-anthropic (0.3.22)
#   - Installing langchain-azure-ai (0.1.8)
#   - Installing langchain-chroma (0.2.3)
#   - Installing langchain-cohere (0.4.6)
#   - Installing langchain-elasticsearch (0.4.0)
#   - Installing langchain-experimental (0.3.4)
#   - Installing langchain-google-genai (2.1.12)
#   - Installing langchain-huggingface (0.3.1)
#   - Installing langchain-milvus (0.2.1)
#   - Installing langchain-ollama (0.3.10)
#   - Installing langchain-teddynote (0.5.4)
#   - Installing langchainhub (0.1.21)
#   - Installing llama-index-readers-file (0.2.2)
#   - Installing llama-parse (0.6.21)
#   - Installing mypy (1.18.2)
#   - Installing open-clip-torch (2.32.0)
#   - Installing pdfplumber (0.11.5)
#   - Installing pinecone (5.4.2)
#   - Installing pymupdf4llm (0.2.0)
#   - Installing ragas (0.3.9)
#   - Installing rapidocr-onnxruntime (1.4.4)
#   - Installing redis (5.3.1)
#   - Installing rouge-score (0.1.2)
#   - Updating scikit-learn (1.6.1 -> 1.7.2)
#   - Installing seaborn (0.13.2)
#   - Installing streamlit (1.51.0)
#   - Installing unstructured (0.18.18)
#   - Installing wikipedia (1.4.0)
#
# Writing lock file
# Installing C:\Users\heesu\AppData\Local\pypoetry\Cache\virtualenvs\langchain-kr-IlBIRnxo-py3.11\Lib\site-packages\jupyterlab_widgets\.gitignore over existing file
# Installing C:\Users\heesu\AppData\Local\pypoetry\Cache\virtualenvs\langchain-kr-IlBIRnxo-py3.11\Lib\site-packages\jupyterlab_widgets\__init__.py over existing file
# Installing C:\Users\heesu\AppData\Local\pypoetry\Cache\virtualenvs\langchain-kr-IlBIRnxo-py3.11\Lib\site-packages\jupyterlab_widgets\_version.py over existing file
# Installing C:\Users\heesu\AppData\Local\pypoetry\Cache\virtualenvs\langchain-kr-IlBIRnxo-py3.11\share\jupyter\labextensions\@jupyter-widgets\jupyterlab-manager\build_log.json over existing file
# Installing C:\Users\heesu\AppData\Local\pypoetry\Cache\virtualenvs\langchain-kr-IlBIRnxo-py3.11\share\jupyter\labextensions\@jupyter-widgets\jupyterlab-manager\package.json over existing file
# Installing C:\Users\heesu\AppData\Local\pypoetry\Cache\virtualenvs\langchain-kr-IlBIRnxo-py3.11\share\jupyter\labextensions\@jupyter-widgets\jupyterlab-manager\schemas\@jupyter-widgets\jupyterlab-manager\package.json.orig over existing file
# Installing C:\Users\heesu\AppData\Local\pypoetry\Cache\virtualenvs\langchain-kr-IlBIRnxo-py3.11\share\jupyter\labextensions\@jupyter-widgets\jupyterlab-manager\schemas\@jupyter-widgets\jupyterlab-manager\plugin.json over existing file
# Installing C:\Users\heesu\AppData\Local\pypoetry\Cache\virtualenvs\langchain-kr-IlBIRnxo-py3.11\share\jupyter\labextensions\@jupyter-widgets\jupyterlab-manager\static\lib_index_js.56f37fb50492d0d63a45.js over existing file
# Installing C:\Users\heesu\AppData\Local\pypoetry\Cache\virtualenvs\langchain-kr-IlBIRnxo-py3.11\share\jupyter\labextensions\@jupyter-widgets\jupyterlab-manager\static\lib_index_js.56f37fb50492d0d63a45.js.map over existing file
# Installing C:\Users\heesu\AppData\Local\pypoetry\Cache\virtualenvs\langchain-kr-IlBIRnxo-py3.11\share\jupyter\labextensions\@jupyter-widgets\jupyterlab-manager\static\packages_base-manager_lib_index_js.13941b475e5b5a1ab133.js over existing file
# Installing C:\Users\heesu\AppData\Local\pypoetry\Cache\virtualenvs\langchain-kr-IlBIRnxo-py3.11\share\jupyter\labextensions\@jupyter-widgets\jupyterlab-manager\static\packages_base-manager_lib_index_js.13941b475e5b5a1ab133.js.map over existing file
# Installing C:\Users\heesu\AppData\Local\pypoetry\Cache\virtualenvs\langchain-kr-IlBIRnxo-py3.11\share\jupyter\labextensions\@jupyter-widgets\jupyterlab-manager\static\packages_base_lib_index_js-webpack_sharing_consume_default_jquery_jquery.5dd13f8e980fa3c50bfe.js over existing file
# Installing C:\Users\heesu\AppData\Local\pypoetry\Cache\virtualenvs\langchain-kr-IlBIRnxo-py3.11\share\jupyter\labextensions\@jupyter-widgets\jupyterlab-manager\static\packages_base_lib_index_js-webpack_sharing_consume_default_jquery_jquery.5dd13f8e980fa3c50bfe.js.map over existing file
# Installing C:\Users\heesu\AppData\Local\pypoetry\Cache\virtualenvs\langchain-kr-IlBIRnxo-py3.11\share\jupyter\labextensions\@jupyter-widgets\jupyterlab-manager\static\packages_controls_lib_index_js.6d5d05e0ec5e0c9f8185.js over existing file
# Installing C:\Users\heesu\AppData\Local\pypoetry\Cache\virtualenvs\langchain-kr-IlBIRnxo-py3.11\share\jupyter\labextensions\@jupyter-widgets\jupyterlab-manager\static\packages_controls_lib_index_js.6d5d05e0ec5e0c9f8185.js.map over existing file
# Installing C:\Users\heesu\AppData\Local\pypoetry\Cache\virtualenvs\langchain-kr-IlBIRnxo-py3.11\share\jupyter\labextensions\@jupyter-widgets\jupyterlab-manager\static\packages_controls_lib_version_js.105c0edf5e497d01e132.js over existing file
# Installing C:\Users\heesu\AppData\Local\pypoetry\Cache\virtualenvs\langchain-kr-IlBIRnxo-py3.11\share\jupyter\labextensions\@jupyter-widgets\jupyterlab-manager\static\packages_controls_lib_version_js.105c0edf5e497d01e132.js.map over existing file
# Installing C:\Users\heesu\AppData\Local\pypoetry\Cache\virtualenvs\langchain-kr-IlBIRnxo-py3.11\share\jupyter\labextensions\@jupyter-widgets\jupyterlab-manager\static\packages_output_lib_index_js.49c9e4037a3b9e9e3b18.js over existing file
# Installing C:\Users\heesu\AppData\Local\pypoetry\Cache\virtualenvs\langchain-kr-IlBIRnxo-py3.11\share\jupyter\labextensions\@jupyter-widgets\jupyterlab-manager\static\packages_output_lib_index_js.49c9e4037a3b9e9e3b18.js.map over existing file
# Installing C:\Users\heesu\AppData\Local\pypoetry\Cache\virtualenvs\langchain-kr-IlBIRnxo-py3.11\share\jupyter\labextensions\@jupyter-widgets\jupyterlab-manager\static\remoteEntry.9077b3d2deaffb329dfc.js over existing file
# Installing C:\Users\heesu\AppData\Local\pypoetry\Cache\virtualenvs\langchain-kr-IlBIRnxo-py3.11\share\jupyter\labextensions\@jupyter-widgets\jupyterlab-manager\static\remoteEntry.9077b3d2deaffb329dfc.js.map over existing file
# Installing C:\Users\heesu\AppData\Local\pypoetry\Cache\virtualenvs\langchain-kr-IlBIRnxo-py3.11\share\jupyter\labextensions\@jupyter-widgets\jupyterlab-manager\static\style.js over existing file
# Installing C:\Users\heesu\AppData\Local\pypoetry\Cache\virtualenvs\langchain-kr-IlBIRnxo-py3.11\share\jupyter\labextensions\@jupyter-widgets\jupyterlab-manager\static\vendors-node_modules_backbone_backbone_js-node_modules_lodash_isEqual_js.ab532abfb6832a50f59e.js over existing file
# Installing C:\Users\heesu\AppData\Local\pypoetry\Cache\virtualenvs\langchain-kr-IlBIRnxo-py3.11\share\jupyter\labextensions\@jupyter-widgets\jupyterlab-manager\static\vendors-node_modules_backbone_backbone_js-node_modules_lodash_isEqual_js.ab532abfb6832a50f59e.js.map over existing file
# Installing C:\Users\heesu\AppData\Local\pypoetry\Cache\virtualenvs\langchain-kr-IlBIRnxo-py3.11\share\jupyter\labextensions\@jupyter-widgets\jupyterlab-manager\static\vendors-node_modules_base64-js_index_js-node_modules_sanitize-html_index_js.c79fc2bcc3f69676beda.js over existing file
# Installing C:\Users\heesu\AppData\Local\pypoetry\Cache\virtualenvs\langchain-kr-IlBIRnxo-py3.11\share\jupyter\labextensions\@jupyter-widgets\jupyterlab-manager\static\vendors-node_modules_base64-js_index_js-node_modules_sanitize-html_index_js.c79fc2bcc3f69676beda.js.map over existing file
# Installing C:\Users\heesu\AppData\Local\pypoetry\Cache\virtualenvs\langchain-kr-IlBIRnxo-py3.11\Scripts\llama-parse.exe over existing file
# Installing C:\Users\heesu\AppData\Local\pypoetry\Cache\virtualenvs\langchain-kr-IlBIRnxo-py3.11\Lib\site-packages\pinecone\__init__.py over existing file
# Installing C:\Users\heesu\AppData\Local\pypoetry\Cache\virtualenvs\langchain-kr-IlBIRnxo-py3.11\Lib\site-packages\pinecone\__version__ over existing file

# %%
# API KEY를 환경변수로 관리하기 위한 설정 파일
from dotenv import load_dotenv

# API KEY 정보로드
load_dotenv()
# Out:
# True

# %% [markdown]
# API Key 가 잘 설정되었는지 확인합니다.

# %%
import os

# print(f"[API KEY]\n{os.environ['OPENAI_API_KEY'][:-15]}" + "*" * 15)

# %% [markdown]
# 설치된 LangChain 버전을 확인합니다.

# %%
from importlib.metadata import version

print("[LangChain 관련 패키지 버전]")
for package_name in [
    "langchain",
    "langchain-core",
    "langchain-experimental",
    "langchain-community",
    "langchain-openai",
    "langchain-teddynote",
    "langchain-huggingface",
    "langchain-google-genai",
    "langchain-anthropic",
    "langchain-cohere",
    "langchain-chroma",
    "langchain-elasticsearch",
    "langchain-upstage",
    "langchain-cohere",
    "langchain-milvus",
    "langchain-text-splitters",
]:
    try:
        package_version = version(package_name)
        print(f"{package_name}: {package_version}")
    except ImportError:
        print(f"{package_name}: 설치되지 않음")
# Out:
# [LangChain 관련 패키지 버전]
# langchain: 0.3.27
# langchain-core: 0.3.79
# langchain-experimental: 0.3.4
# langchain-community: 0.3.31
# langchain-openai: 0.3.35
# langchain-teddynote: 0.5.4
# langchain-huggingface: 0.3.1
# langchain-google-genai: 2.1.12
# langchain-anthropic: 0.3.22
# langchain-cohere: 0.4.6
# langchain-chroma: 0.2.3
# langchain-elasticsearch: 0.4.0
# langchain-upstage: 설치되지 않음
# langchain-cohere: 0.4.6
# langchain-milvus: 0.2.1
# langchain-text-splitters: 0.3.11
